# %% [markdown]
# # Importing Libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Data

# %%
# Import data

# Assign the path variable 

path = r'C:\Users\guest23455\Desktop\CareerFoundry\Data Immersion\Achievement 6_Advanced Analytics and Dashboard Design\06-2023 Apartment Rental in Germany Analysis'

# %%
# Import the immo data

df = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'immo_data.csv'), index_col = False)

# %%
df.head(10)
# Out:
#                 regio1  serviceCharge                     heatingType  \
# 0  Nordrhein_Westfalen         245.00                 central_heating
# 1      Rheinland_Pfalz         134.00  self_contained_central_heating
# 2              Sachsen         255.00                   floor_heating
# 3              Sachsen          58.15                district_heating
# 4               Bremen         138.00  self_contained_central_heating
# 5   Schleswig_Holstein         142.00                     gas_heating
# 6              Sachsen          70.00  self_contained_central_heating
# 7               Bremen          88.00                 central_heating
# 8    Baden_Württemberg         110.00                     oil_heating
# 9  Nordrhein_Westfalen          95.00  self_contained_central_heating
#
#   telekomTvOffer  telekomHybridUploadSpeed  newlyConst  balcony  picturecount  \
# 0  ONE_YEAR_FREE                       NaN       False    False             6
# ...

# %%
df.columns
# Out:
# Index(['regio1', 'serviceCharge', 'heatingType', 'telekomTvOffer',
#        'telekomHybridUploadSpeed', 'newlyConst', 'balcony', 'picturecount',
#        'pricetrend', 'telekomUploadSpeed', 'totalRent', 'yearConstructed',
#        'scoutId', 'noParkSpaces', 'firingTypes', 'hasKitchen', 'geo_bln',
#        'cellar', 'yearConstructedRange', 'baseRent', 'houseNumber',
#        'livingSpace', 'geo_krs', 'condition', 'interiorQual', 'petsAllowed',
#        'street', 'streetPlain', 'lift', 'baseRentRange', 'typeOfFlat',
#        'geo_plz', 'noRooms', 'thermalChar', 'floor', 'numberOfFloors',
#        'noRoomsRange', 'garden', 'livingSpaceRange', 'regio2', 'regio3',
#        'description', 'facilities', 'heatingCosts', 'energyEfficiencyClass',
#        'lastRefurbish', 'electricityBasePrice', 'electricityKwhPrice', 'date'],
#       dtype='object')

# %% [markdown]
# # Checking for Data Quality Issues

# %%
# Explore the data 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268850 entries, 0 to 268849
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   regio1                    268850 non-null  object
#  1   serviceCharge             261941 non-null  float64
#  2   heatingType               223994 non-null  object
#  3   telekomTvOffer            236231 non-null  object
#  4   telekomHybridUploadSpeed  45020 non-null   float64
#  5   newlyConst                268850 non-null  bool
#  6   balcony                   268850 non-null  bool
#  7   picturecount              268850 non-null  int64
#  8   pricetrend                267018 non-null  float64
#  9   telekomUploadSpeed        235492 non-null  float64
#  10  totalRent                 228333 non-null  float64
#  11  yearConstructed           211805 non-null  float64
#  12  scoutId                   268850 non-null  int64
# ...

# %%
# Descriptive Statistics

df.describe()
# Out:
#        serviceCharge  telekomHybridUploadSpeed   picturecount     pricetrend  \
# count  261941.000000                   45020.0  268850.000000  267018.000000
# mean      151.206113                      10.0       9.791958       3.389001
# std       308.295790                       0.0       6.408399       1.964874
# min         0.000000                      10.0       0.000000     -12.330000
# 25%        95.000000                      10.0       6.000000       2.000000
# 50%       135.000000                      10.0       9.000000       3.390000
# 75%       190.000000                      10.0      13.000000       4.570000
# max    146118.000000                      10.0     121.000000      14.920000
#
#        telekomUploadSpeed     totalRent  yearConstructed       scoutId  \
# count       235492.000000  2.283330e+05    211805.000000  2.688500e+05
# mean            28.804928  9.013315e+02      1966.400590  1.069697e+08
# ...

# %%
# Check for mixed-types

# Function for checking whether a datframe contains any mixed-type columns :

for col in df.columns.tolist():
    weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)   # Weird (boolean value) : a new variable is created, which checks if the data types within the column are consistent
    if len (df[weird]) > 0:          # 0 : False and 1 : True; So if the value is True , i.e 1 ,then it will print the column name
        print(col)
# Out:
# heatingType
# telekomTvOffer
# firingTypes
# houseNumber
# condition
# interiorQual
# petsAllowed
# streetPlain
# typeOfFlat
# description
# facilities
# energyEfficiencyClass

# %% [markdown]
# I will not change the data types of the above columns becuase they are not requiered for analysis.

# %%
# Missing values

df.isnull().sum()
# Out:
# regio1                           0
# serviceCharge                 6909
# heatingType                  44856
# telekomTvOffer               32619
# telekomHybridUploadSpeed    223830
# newlyConst                       0
# balcony                          0
# picturecount                     0
# pricetrend                    1832
# telekomUploadSpeed           33358
# totalRent                    40517
# yearConstructed              57045
# scoutId                          0
# noParkSpaces                175798
# firingTypes                  56964
# hasKitchen                       0
# geo_bln                          0
# cellar                           0
# yearConstructedRange         57045
# baseRent                         0
# houseNumber                  71018
# livingSpace                      0
# geo_krs                          0
# condition                    68489
# interiorQual                112665
# petsAllowed                 114573
# street                           0
# ...

# %%
# Dropping unwanted columns

drop_columns = (['telekomTvOffer', 'telekomHybridUploadSpeed', 'telekomUploadSpeed','scoutId', 'firingTypes', 'houseNumber', 'condition', 'interiorQual','streetPlain', 'thermalChar','description', 'facilities', 'energyEfficiencyClass', 'electricityBasePrice', 'electricityKwhPrice', 'date'])

# %%
drop_columns
# Out:
# ['telekomTvOffer',
#  'telekomHybridUploadSpeed',
#  'telekomUploadSpeed',
#  'scoutId',
#  'firingTypes',
#  'houseNumber',
#  'condition',
#  'interiorQual',
#  'streetPlain',
#  'thermalChar',
#  'description',
#  'facilities',
#  'energyEfficiencyClass',
#  'electricityBasePrice',
#  'electricityKwhPrice',
#  'date']

# %%
df.drop(drop_columns, axis=1, inplace=True)

# %%
df
# Out:
#                      regio1  serviceCharge                     heatingType  \
# 0       Nordrhein_Westfalen         245.00                 central_heating
# 1           Rheinland_Pfalz         134.00  self_contained_central_heating
# 2                   Sachsen         255.00                   floor_heating
# 3                   Sachsen          58.15                district_heating
# 4                    Bremen         138.00  self_contained_central_heating
# ...                     ...            ...                             ...
# 268845               Bayern          90.00                       heat_pump
# 268846               Hessen         220.00                     gas_heating
# 268847               Hessen         220.00                 central_heating
# 268848  Nordrhein_Westfalen         175.00                       heat_pump
# 268849               Hessen         315.00                 central_heating
#
#         newlyConst  balcony  picturecount  pricetrend  totalRent  \
# ...

# %%
df.columns
# Out:
# Index(['regio1', 'serviceCharge', 'heatingType', 'newlyConst', 'balcony',
#        'picturecount', 'pricetrend', 'totalRent', 'yearConstructed',
#        'noParkSpaces', 'hasKitchen', 'geo_bln', 'cellar',
#        'yearConstructedRange', 'baseRent', 'livingSpace', 'geo_krs',
#        'petsAllowed', 'street', 'lift', 'baseRentRange', 'typeOfFlat',
#        'geo_plz', 'noRooms', 'floor', 'numberOfFloors', 'noRoomsRange',
#        'garden', 'livingSpaceRange', 'regio2', 'regio3', 'heatingCosts',
#        'lastRefurbish'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268850 entries, 0 to 268849
# Data columns (total 33 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   regio1                268850 non-null  object
#  1   serviceCharge         261941 non-null  float64
#  2   heatingType           223994 non-null  object
#  3   newlyConst            268850 non-null  bool
#  4   balcony               268850 non-null  bool
#  5   picturecount          268850 non-null  int64
#  6   pricetrend            267018 non-null  float64
#  7   totalRent             228333 non-null  float64
#  8   yearConstructed       211805 non-null  float64
#  9   noParkSpaces          93052 non-null   float64
#  10  hasKitchen            268850 non-null  bool
#  11  geo_bln               268850 non-null  object
#  12  cellar                268850 non-null  bool
#  13  yearConstructedRange  211805 non-null  float64
# ...

# %% [markdown]
# The data type of Year of construction should be int, but it is float

# %%
# Missing values

df.isnull().sum()
# Out:
# regio1                       0
# serviceCharge             6909
# heatingType              44856
# newlyConst                   0
# balcony                      0
# picturecount                 0
# pricetrend                1832
# totalRent                40517
# yearConstructed          57045
# noParkSpaces            175798
# hasKitchen                   0
# geo_bln                      0
# cellar                       0
# yearConstructedRange     57045
# baseRent                     0
# livingSpace                  0
# geo_krs                      0
# petsAllowed             114573
# street                       0
# lift                         0
# baseRentRange                0
# typeOfFlat               36614
# geo_plz                      0
# noRooms                      0
# floor                    51309
# numberOfFloors           97732
# noRoomsRange                 0
# garden                       0
# livingSpaceRange             0
# regio2                       0
# ...

# %%
# After further analysis, I would like to drop more columns

drop_columns1 = (['heatingType','yearConstructedRange','baseRentRange','noRoomsRange','livingSpaceRange','lastRefurbish','typeOfFlat','geo_krs','street'])

# %%
df.drop(drop_columns1, axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268850 entries, 0 to 268849
# Data columns (total 24 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   regio1           268850 non-null  object
#  1   serviceCharge    261941 non-null  float64
#  2   newlyConst       268850 non-null  bool
#  3   balcony          268850 non-null  bool
#  4   picturecount     268850 non-null  int64
#  5   pricetrend       267018 non-null  float64
#  6   totalRent        228333 non-null  float64
#  7   yearConstructed  211805 non-null  float64
#  8   noParkSpaces     93052 non-null   float64
#  9   hasKitchen       268850 non-null  bool
#  10  geo_bln          268850 non-null  object
#  11  cellar           268850 non-null  bool
#  12  baseRent         268850 non-null  float64
#  13  livingSpace      268850 non-null  float64
#  14  petsAllowed      154277 non-null  object
#  15  lift             268850 non-null  bool
# ...

# %%
df.isnull().sum()
# Out:
# regio1                  0
# serviceCharge        6909
# newlyConst              0
# balcony                 0
# picturecount            0
# pricetrend           1832
# totalRent           40517
# yearConstructed     57045
# noParkSpaces       175798
# hasKitchen              0
# geo_bln                 0
# cellar                  0
# baseRent                0
# livingSpace             0
# petsAllowed        114573
# lift                    0
# geo_plz                 0
# noRooms                 0
# floor               51309
# numberOfFloors      97732
# garden                  0
# regio2                  0
# regio3                  0
# heatingCosts       183332
# dtype: int64

# %%
# Handling missing values
# Replacing missing quantitative values with 0

df[['serviceCharge', 'pricetrend','totalRent','yearConstructed','noParkSpaces','floor','numberOfFloors','heatingCosts']] = df[['serviceCharge', 'pricetrend','totalRent','yearConstructed','noParkSpaces','floor','numberOfFloors','heatingCosts']].fillna(value=0)

# %%
# Replacing missing categorical values with Not Mentioned

df['petsAllowed'] = df['petsAllowed'].fillna(value='Not Mentioned')

# %%
df.isnull().sum()
# Out:
# regio1             0
# serviceCharge      0
# newlyConst         0
# balcony            0
# picturecount       0
# pricetrend         0
# totalRent          0
# yearConstructed    0
# noParkSpaces       0
# hasKitchen         0
# geo_bln            0
# cellar             0
# baseRent           0
# livingSpace        0
# petsAllowed        0
# lift               0
# geo_plz            0
# noRooms            0
# floor              0
# numberOfFloors     0
# garden             0
# regio2             0
# regio3             0
# heatingCosts       0
# dtype: int64

# %%
df.shape
# Out:
# (268850, 24)

# %%
# Check for duplicate values

df_dups = df[df.duplicated()]

# %%
# View duplicate values

df_dups
# Out:
#                      regio1  serviceCharge  newlyConst  balcony  picturecount  \
# 2811                Sachsen         220.00       False    False            14
# 5095                Sachsen         220.00       False    False            14
# 9410                Sachsen         260.00        True     True             4
# 11589               Sachsen         141.00       False     True             5
# 11601   Nordrhein_Westfalen          35.00       False    False             5
# ...                     ...            ...         ...      ...           ...
# 268101  Nordrhein_Westfalen         153.50       False     True             3
# 268213  Nordrhein_Westfalen         120.00       False    False             9
# 268259       Sachsen_Anhalt         142.75       False     True            13
# 268560   Schleswig_Holstein          80.40       False    False             2
# 268786              Sachsen         255.43        True     True             1
#
# ...

# %% [markdown]
# There were 1836 duplicate rows. I will create a new df excluding the duplicate values.

# %%
df_dup_clean = df.drop_duplicates()

# %%
df_dup_clean.shape
# Out:
# (266909, 24)

# %%
df_dup_clean.columns
# Out:
# Index(['regio1', 'serviceCharge', 'newlyConst', 'balcony', 'picturecount',
#        'pricetrend', 'totalRent', 'yearConstructed', 'noParkSpaces',
#        'hasKitchen', 'geo_bln', 'cellar', 'baseRent', 'livingSpace',
#        'petsAllowed', 'lift', 'geo_plz', 'noRooms', 'floor', 'numberOfFloors',
#        'garden', 'regio2', 'regio3', 'heatingCosts'],
#       dtype='object')

# %%
# Rename columns

df_dup_clean = df_dup_clean.rename(columns = {'regio1' : 'State', 'geo_plz' : 'Zipcode','regio2' : 'City', 'regio3' : 'Districts'})

# %%
df_dup_clean = df_dup_clean.rename(columns = {'serviceCharge' : 'Service_Charge', 'newlyConst' : 'Newly_Constructed', 'balcony' : 'Balcony', 'picturecount' : 'Picture_Count', 'pricetrend' : 'Price_Trend', 'totalRent' : 'Total_Rent', 'yearConstructed' : 'Year_Constructed', 'noParkSpaces' : 'Number of Parking Spaces', 'hasKitchen':'Has_Kitchen','cellar':'Cellar', 'baseRent':'Base_Rent', 'livingSpace' : 'Area (m2)', 'petsAllowed' : 'Pets_Allowed', 'lift' :'Lift', 'noRooms' : 'Number of Rooms', 'floor' : 'Floor', 'numberOfFloors' : 'Number of Floors', 'garden' : 'Has_Garden', 'heatingCosts' : 'Heating_Costs' })

# %%
# Changing data type of yearConstructed

df_dup_clean['Year_Constructed'] = df_dup_clean['Year_Constructed'].astype('int')

# %%
df_dup_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 266909 entries, 0 to 268849
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   State                     266909 non-null  object
#  1   Service_Charge            266909 non-null  float64
#  2   Newly_Constructed         266909 non-null  bool
#  3   Balcony                   266909 non-null  bool
#  4   Picture_Count             266909 non-null  int64
#  5   Price_Trend               266909 non-null  float64
#  6   Total_Rent                266909 non-null  float64
#  7   Year_Constructed          266909 non-null  int32
#  8   Number of Parking Spaces  266909 non-null  float64
#  9   Has_Kitchen               266909 non-null  bool
#  10  geo_bln                   266909 non-null  object
#  11  Cellar                    266909 non-null  bool
#  12  Base_Rent                 266909 non-null  float64
# ...

# %%
df_dup_clean['Year_Constructed'].describe()
# Out:
# count    266909.000000
# mean       1548.838188
# std         805.213594
# min           0.000000
# 25%        1900.000000
# 50%        1962.000000
# 75%        1992.000000
# max        2090.000000
# Name: Year_Constructed, dtype: float64

# %% [markdown]
# The value 2090 is an outlier.

# %%
df_dup_clean['Year_Constructed'].value_counts()
# Out:
# 0       56670
# 2019    10753
# 1900    10307
# 2018     8637
# 1995     4363
#         ...
# 1586        1
# 1027        1
# 1787        1
# 1627        1
# 1472        1
# Name: Year_Constructed, Length: 466, dtype: int64

# %% [markdown]
# I would like to consider the data above 1800. So I would like to anlyse the data from 1800 to 2023.

# %%
df_immo = df_dup_clean[(df_dup_clean['Year_Constructed'] < 2023) & (df_dup_clean['Year_Constructed'] > 1800)]

# %%
df_immo['Year_Constructed'].value_counts()
# Out:
# 2019    10753
# 1900    10307
# 2018     8637
# 1995     4363
# 1996     4326
#         ...
# 1822        1
# 1814        1
# 1817        1
# 1811        1
# 1804        1
# Name: Year_Constructed, Length: 218, dtype: int64

# %%
df_immo.shape
# Out:
# (209208, 24)

# %%
df_immo['Year_Constructed'].describe()
# Out:
# count    209208.000000
# mean       1967.947913
# std          38.445865
# min        1803.000000
# 25%        1950.000000
# 50%        1973.000000
# 75%        1996.000000
# max        2022.000000
# Name: Year_Constructed, dtype: float64

# %% [markdown]
# # Exporting Data

# %%
df_immo.to_csv(os.path.join(path,'Data','Prepared Data','immodata_cleaned.csv'))

# %%
df_immo.head()
# Out:
#                  State  Service_Charge  Newly_Constructed  Balcony  \
# 0  Nordrhein_Westfalen          245.00              False    False
# 1      Rheinland_Pfalz          134.00              False     True
# 2              Sachsen          255.00               True     True
# 3              Sachsen           58.15              False     True
# 4               Bremen          138.00              False     True
#
#    Picture_Count  Price_Trend  Total_Rent  Year_Constructed  \
# 0              6         4.62       840.0              1965
# 1              8         3.47         0.0              1871
# 2              8         2.72      1300.0              2019
# 3              9         1.53         0.0              1964
# 4             19         2.46       903.0              1950
#
#    Number of Parking Spaces  Has_Kitchen  ...   Pets_Allowed   Lift  Zipcode  \
# 0                       1.0        False  ...  Not Mentioned  False    44269
# ...
